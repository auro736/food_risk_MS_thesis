# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import torch
import transformers
import datasets
import shap


# load the emotion dataset
dataset  = datasets.load_dataset("emotion", split = "train")
data = pd.DataFrame({'text':dataset['text'],'emotion':dataset['label']})


# load the model and tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained("nateraw/bert-base-uncased-emotion", use_fast=True)
model = transformers.AutoModelForSequenceClassification.from_pretrained("nateraw/bert-base-uncased-emotion").cuda()
labels = sorted(model.config.label2id, key=model.config.label2id.get)

# this defines an explicit python function that takes a list of strings and outputs scores for each class
def f(x):
    tv = torch.tensor([tokenizer.encode(v, padding='max_length', max_length=128, truncation=True) for v in x]).cuda()
    attention_mask = (tv!=0).type(torch.int64).cuda()
    outputs = model(tv,attention_mask=attention_mask)[0].detach().cpu().numpy()
    scores = (np.exp(outputs).T / np.exp(outputs).sum(-1)).T
    val = sp.special.logit(scores)
    return val

explainer = shap.Explainer(f, tokenizer, output_names=labels)
print(type(data['text'][:3]))
shap_values = explainer(data['text'][:3])

shap.plots.text(shap_values)
# Out:
# No config specified, defaulting to: emotion/split
# Found cached dataset emotion (/home/cc/.cache/huggingface/datasets/emotion/split/1.0.0/cca5efe2dfeb58c1d098e0f9eeb200e9927d889b5a03c67097275dfb5fe463bd)
# <class 'pandas.core.series.Series'>
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_jwhzebpydtpgmrjizgcp = '_tp_jwhzebpydtpgmrjizgcp_output_0';
#     document._zoom_jwhzebpydtpgmrjizgcp = undefined;
#     function _output_onclick_jwhzebpydtpgmrjizgcp(i) {
#         var next_id = undefined;
#
#         if (document._zoom_jwhzebpydtpgmrjizgcp !== undefined) {
#             document.getElementById(document._zoom_jwhzebpydtpgmrjizgcp+ '_zoom').style.display = 'none';
#
#             if (document._zoom_jwhzebpydtpgmrjizgcp === '_tp_jwhzebpydtpgmrjizgcp_output_' + i) {
#                 document.getElementById(document._zoom_jwhzebpydtpgmrjizgcp).style.display = 'block';
#                 document.getElementById(document._zoom_jwhzebpydtpgmrjizgcp+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_jwhzebpydtpgmrjizgcp).style.display = 'none';
#                 document.getElementById(document._zoom_jwhzebpydtpgmrjizgcp+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_jwhzebpydtpgmrjizgcp !== '_tp_jwhzebpydtpgmrjizgcp_output_' + i) {
#             next_id = '_tp_jwhzebpydtpgmrjizgcp_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_jwhzebpydtpgmrjizgcp = next_id;
#     }
#     function _output_onmouseover_jwhzebpydtpgmrjizgcp(i, el) {
#         if (document._zoom_jwhzebpydtpgmrjizgcp !== undefined) { return; }
#         if (document._hover_jwhzebpydtpgmrjizgcp !== undefined) {
#             document.getElementById(document._hover_jwhzebpydtpgmrjizgcp + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_jwhzebpydtpgmrjizgcp).style.display = 'none';
#         }
#         document.getElementById('_tp_jwhzebpydtpgmrjizgcp_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_jwhzebpydtpgmrjizgcp = '_tp_jwhzebpydtpgmrjizgcp_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.7162210338680925); border-radius: 3px; padding: 0px" id="_tp_jwhzebpydtpgmrjizgcp_output_0_name"
#     onclick="_output_onclick_jwhzebpydtpgmrjizgcp(0)"
#     onmouseover="_output_onmouseover_jwhzebpydtpgmrjizgcp(0, this);">sadness</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9290552584670232); border-radius: 3px; padding: 0px" id="_tp_jwhzebpydtpgmrjizgcp_output_1_name"
#     onclick="_output_onclick_jwhzebpydtpgmrjizgcp(1)"
#     onmouseover="_output_onmouseover_jwhzebpydtpgmrjizgcp(1, this);">joy</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9369380075262429); border-radius: 3px; padding: 0px" id="_tp_jwhzebpydtpgmrjizgcp_output_2_name"
#     onclick="_output_onclick_jwhzebpydtpgmrjizgcp(2)"
#     onmouseover="_output_onmouseover_jwhzebpydtpgmrjizgcp(2, this);">love</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.8502277678748268); border-radius: 3px; padding: 0px" id="_tp_jwhzebpydtpgmrjizgcp_output_3_name"
#     onclick="_output_onclick_jwhzebpydtpgmrjizgcp(3)"
#     onmouseover="_output_onmouseover_jwhzebpydtpgmrjizgcp(3, this);">anger</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9369380075262429); border-radius: 3px; padding: 0px" id="_tp_jwhzebpydtpgmrjizgcp_output_4_name"
#     onclick="_output_onclick_jwhzebpydtpgmrjizgcp(4)"
#     onmouseover="_output_onmouseover_jwhzebpydtpgmrjizgcp(4, this);">fear</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_jwhzebpydtpgmrjizgcp_output_5_name"
#     onclick="_output_onclick_jwhzebpydtpgmrjizgcp(5)"
#     onmouseover="_output_onmouseover_jwhzebpydtpgmrjizgcp(5, this);">surprise</div><br><br><div id='_tp_jwhzebpydtpgmrjizgcp_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.967993247455695%" y1="33" x2="49.967993247455695%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.967993247455695%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="34.27678608444971%" y1="33" x2="34.27678608444971%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.27678608444971%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="18.585578921443734%" y1="33" x2="18.585578921443734%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.585578921443734%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="65.65920041046168%" y1="33" x2="65.65920041046168%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.65920041046168%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="81.35040757346766%" y1="33" x2="81.35040757346766%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.35040757346766%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">5</text><line x1="45.332505385743644%" y1="33" x2="45.332505385743644%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="45.332505385743644%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-1.88626</text><text x="45.332505385743644%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1.88626</text><text x="45.332505385743644%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="84.6217285324566%" y1="33" x2="84.6217285324566%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="84.6217285324566%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">5.62544</text><text x="84.6217285324566%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">5.62544</text><text x="84.6217285324566%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">sadness</tspan>(inputs)</text><rect x="45.33250429459668%" width="39.289224237859926%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="48.526966653813055%" x2="84.6217285324566%" y1="60" y2="60" id="_fb_ttgrlgjqzffwrrezlsro_ind_5" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.57434759313483%" y="71" font-size="12px" id="_fs_ttgrlgjqzffwrrezlsro_ind_5" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">6.901</text><svg x="48.526966653813055%" y="40" height="20" width="36.094761878643546%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">hu
